# %%
import pandas as pd

data = pd.DataFrame({'usefull': [100,200,300], 'useless': [0,0,0]})
display(data)
# Out:
#    usefull  useless
# 0      100        0
# 1      200        0
# 2      300        0
